# %% [markdown]
# # Windninja Pipeline

# %% [markdown]
# ## 1. Import & install neccessary packages

# %%
import os
import subprocess
from pathlib import Path
from datetime import datetime, timedelta, timezone
from dateutil import tz
import pandas as pd
from sqlalchemy import create_engine, text
import shutil, subprocess

# %% [markdown]
# ## 2. Set variables

# %%
WINDNINJA_CLI=Path(r"C:\Program Files (x86)\WindNinja\WindNinja-3.12.0\bin\WindNinja_cli.exe")
BASE_OUT = Path("windninja_output")

# %%
# ------------------ USER SETTINGS ------------------

# DEM used by WindNinja
ELEVATION_FILE = r"merlingen_7.5mi.tif"

# Vegetation & heights
VEGETATION = "trees"           # grass | trees | brush (set to your dominant cover)
OUTPUT_WIND_HEIGHT = 10.0     # meters AGL for output
OUTPUT_SPEED_UNITS = "mps"     # m/s | mph | kph
TIMEZONE = "Europe/Zurich"     # must be a valid IANA tz string


# Mesh resolution (meters)
MESH_RES_M = 150.0

# %%
# Date/time window to process 
START = datetime(2025, 10, 30, 18, 0, tzinfo=tz.gettz(TIMEZONE))
END   = datetime(2025, 10, 30, 18, 50, tzinfo=tz.gettz(TIMEZONE)) 

# 6 timesteps (local) within this hour:
NR_TIMESTEPS = 6

# %%
# Connect to wind database

engine = create_engine(
    f"mysql+pymysql://{os.getenv('DB_USER')}:{os.getenv('DB_PASS')}"
    f"@{os.getenv('DB_HOST')}:{int(os.getenv('DB_PORT', 3306))}/{os.getenv('DB_NAME')}",
    pool_pre_ping=True,
    future=True,
)

# Three station views from database
VIEWS = ["v_windninja_export_fru", "v_windninja_export_int", "v_windninja_export_thu"] 

# time in views CET/CEST automatically handled
LOCAL_TZ = tz.gettz("Europe/Zurich")

# The exact column order you said the view provides:
WN_HEADERS = [
    "Station_Name","Coord_Sys(PROJCS,GEOGCS)","Datum(WGS84,NAD83,NAD27)",
    "Lat/YCoord","Lon/XCoord","Height","Height_Units(meters,feet)",
    "Speed","Speed_Units(mph,kph,mps,kts)","Direction(degrees)",
    "Temperature","Temperature_Units(F,C)","Cloud_Cover(%)",
    "Radius_of_Influence","Radius_of_Influence_Units(miles,feet,meters,km)",
    "date_time"
]

# %%
try:
    with engine.connect() as connection:
        print("✅ Connection successful!")
except Exception as e:
    print("❌ Connection failed!")
    print(e)
# Out:
# ✅ Connection successful!

# %% [markdown]
# ## 2. Define Helper Functions

# %% [markdown]
# Source: https://github.com/gagreene/WindNinja/
# Source: https://github.com/firelab/windninja

# %%
def _local_day_to_utc_bounds(any_local_dt: datetime):
    """
    Given a LOCAL datetime, return UTC bounds covering the UTC calendar day
    that has the *same Y-M-D* as the local date.

    Example:
      input  2025-08-31 06:00+02 -> returns
      start_utc = 2025-08-31 00:00:00Z (naive)
      end_utc   = 2025-09-01 00:00:00Z (naive, exclusive)
    """
    # Ensure we interpret the argument in local time (handle naive safely)
    if any_local_dt.tzinfo is None:
        local_dt = any_local_dt.replace(tzinfo=LOCAL_TZ)
    else:
        local_dt = any_local_dt.astimezone(LOCAL_TZ)

    # Take the *local* Y-M-D fields, but build a UTC-day window with the same Y-M-D
    y, m, d = local_dt.year, local_dt.month, local_dt.day
    start_utc_dt = datetime(y, m, d, 0, 0, tzinfo=timezone.utc)
    end_utc_dt   = start_utc_dt + timedelta(days=1)

    # Return naive datetimes for MySQL DATETIME comparison
    return start_utc_dt.replace(tzinfo=None), end_utc_dt.replace(tzinfo=None)

# %%
def _station_code(view: str) -> str:
    v = view.lower()
    if "fru" in v: return "FRU"
    if "int" in v: return "INT"
    if "thu" in v: return "THU"
    return view.split("_")[-1].upper()

# %%
def make_daily_station_filename(view: str, start_local: datetime, end_local: datetime = None, index: int = None) -> str:
    """
    Build: THU-CET-YYYY-MM-DD_0000-yyyy-mm-dd_0000-{index}.csv

    Back-compat:
      - If called with only (view, start_local) as your fetcher does,
        we auto-fill:
          * end_local := global END if present, else start_local
          * index     := stable index from VIEWS order (THU/INT/FRU etc.)
    """
    # infer end_local if not provided (use global END if available)
    if end_local is None:
        end_local = globals().get("END", start_local)

    # infer index if not provided: stable position in VIEWS
    if index is None:
        try:
            index = globals()["VIEWS"].index(view)
        except Exception:
            index = 0

    code      = _station_code(view)
    tz_label  = "CET"
    start_str = start_local.strftime("%Y-%m-%d_0000")
    end_str   = end_local.strftime("%Y-%m-%d_0000")
    return f"{code}-{tz_label}-{start_str}-{end_str}-{index}.csv"

# %%
def fetch_write_daily_station_csvs(engine, out_dir: Path, start_local: datetime) -> dict:
    """
    For each view:
      - Determine the LOCAL day of `start_local`
      - Build UTC bounds for that day
      - Query MySQL by UTC (date_time is UTC in the view)
      - DO NOT CONVERT `date_time` (leave exactly as stored)
      - Enforce column order (names unchanged)
      - Write one CSV per station/day using your naming pattern
    Returns {view: csv_path}.
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    # the local 'day' is derived from the user-provided START (local)
    day_local = start_local.astimezone(LOCAL_TZ).replace(hour=0, minute=0, second=0, microsecond=0)
    start_utc, end_utc = _local_day_to_utc_bounds(day_local)

    sql = """
      SELECT *
      FROM `{view}`
      WHERE `date_time` >= :a AND `date_time` < :b
      ORDER BY `date_time` ASC
    """

    written = {}
    with engine.begin() as conn:
        for view in VIEWS:
            df = pd.read_sql(text(sql.format(view=view)), conn,
                             params={"a": start_utc, "b": end_utc})

            if df.empty:
                # no file written for this view/day
                continue

            # (Important) Do NOT touch df["date_time"]: leave it exactly as stored in DB (UTC)
            # Ensure headers exist and enforce order; this does not change values.
            missing = [c for c in WN_HEADERS if c not in df.columns]
            if missing:
                raise ValueError(f"{view}: missing expected columns: {missing}")
            df = df[WN_HEADERS]

            # Write the CSV with values exactly as read (no datetime conversion/formatting)
            fname = make_daily_station_filename(view, day_local)
            csv_path = out_dir / fname
            df.to_csv(csv_path, index=False)
            written[view] = csv_path

    return written

# %%
def ensure_daily_files(engine, base_out: Path, start_local: datetime, end_local: datetime, views) -> tuple[Path, dict]:
    """
    Create the WXSTATIONS folder and guarantee exactly one CSV per station/day.
    - Reuse existing files (no overwrite).
    - Only create missing ones by calling the unchanged fetcher into a temp folder,
      then moving across the missing files to the target folder.
    Returns (day_folder, {view: path_str})
    """
    tz_label   = "CET"
    folderName = f"WXSTATIONS-{tz_label}-{start_local:%Y-%m-%d_0000}-{end_local:%Y-%m-%d_0000}-lake-thun"
    day_folder = base_out / folderName
    day_folder.mkdir(parents=True, exist_ok=True)

    # Expected filenames (stable indices)
    expected = {}
    for i, view in enumerate(views):
        fname = make_daily_station_filename(view, start_local, end_local, i)
        expected[view] = day_folder / fname

    # What already exists?
    have = {v: p for v, p in expected.items() if p.exists()}
    missing_views = [v for v in views if not expected[v].exists()]

    if not missing_views:
        # Nothing to write; return existing mapping
        return day_folder, {v: str(expected[v]) for v in views if expected[v].exists()}

    # Write all station CSVs for the day into a TEMP folder (using the unchanged fetcher)
    tmp_dir = day_folder / "_tmp_station_write"
    tmp_dir.mkdir(parents=True, exist_ok=True)

    # The fetcher will:
    #  * compute day_local = midnight of START (local)
    #  * call make_daily_station_filename(view, day_local)  <-- now back-compat & stable
    tmp_written = fetch_write_daily_station_csvs(engine, tmp_dir, start_local)  # returns {view: Path}

    # Move only MISSING views into the final folder; leave existing files untouched
    for view in missing_views:
        src = Path(tmp_written.get(view, ""))
        if not src or not src.exists():
            # No data fetched for that view/day; skip
            continue
        dst = expected[view]
        # Ensure the src name matches the expected final name; if not, rename while moving
        if src.name != dst.name:
            shutil.move(str(src), str(dst))
        else:
            shutil.move(str(src), str(dst))

    # Cleanup temp dir if empty
    try:
        tmp_dir.rmdir()
    except OSError:
        pass  # not empty (e.g., some views had no data or something else wrote there)

    # Build final mapping of what now exists
    result = {v: str(p) for v, p in expected.items() if p.exists()}
    return day_folder, result

# %%
# Prepare a list of stations csvs

def create_station_list_csv(day_folder: Path, start_local: datetime, end_local: datetime) -> Path:
    """
    Writes a one-column CSV:
      Station_File_List,
      <filenames for THIS day window only>
    """
    start_str = start_local.strftime("%Y-%m-%d_0000")
    end_str   = end_local.strftime("%Y-%m-%d_0000")

    # Only include files matching this day's window and exclude the list file itself
    station_files = sorted([
        f.name for f in day_folder.glob("*.csv")
        if f.name != f"station_file_list_{start_local:%Y%m%d}.csv"
        and f"-CET-{start_str}-{end_str}-" in f.name
    ])

    if not station_files:
        raise FileNotFoundError(f"No station CSVs for {start_str} → {end_str} in {day_folder}")

    out_csv = day_folder / f"station_file_list_{start_local:%Y%m%d}.csv"
    with open(out_csv, "w", encoding="utf-8", newline="\n") as fh:
        fh.write("Station_File_List,\n")
        for name in station_files:
            fh.write(f"{name}\n")

    return out_csv

# %%
def _as_posix(p):
    # accepts Path or str, returns a forward-slash path (works on Windows)
    return str(Path(p)).replace("\\", "/")

# %%
def build_cfg_point_init_span_cli(cfg_path, output_dir, station_csv, start_local, stop_local, n_steps):
    """
    WindNinja CLI — pointInitialization, NO diurnal, MULTI-step run over [start_local, stop_local],
    with number_time_steps = n_steps (evenly spaced across the span).
    """
    lines = [
        f"num_threads = {os.cpu_count() or 2}",
        f"elevation_file = {_as_posix(ELEVATION_FILE)}",
        "initialization_method = pointInitialization",
        f"wx_station_filename = {_as_posix(station_csv)}",
        "match_points = true",

        # CLI inputs analogous to what the GUI collects:
        f"number_time_steps = {int(n_steps)}",

        f"start_year = {start_local.year}",
        f"start_month = {start_local.month}",
        f"start_day = {start_local.day}",
        f"start_hour = {start_local.hour}",
        f"start_minute = {start_local.minute}",

        f"stop_year = {stop_local.year}",
        f"stop_month = {stop_local.month}",
        f"stop_day = {stop_local.day}",
        f"stop_hour = {stop_local.hour}",
        f"stop_minute = {stop_local.minute}",

        f"time_zone = {TIMEZONE}",
        f"vegetation = {VEGETATION}",
        "diurnal_winds = false",

        f"mesh_resolution = {int(MESH_RES_M)}",
        "units_mesh_resolution = m",
        f"output_wind_height = {float(OUTPUT_WIND_HEIGHT)}",
        "units_output_wind_height = m",
        F"output_speed_units = {OUTPUT_SPEED_UNITS}",

        f"output_path = {_as_posix(output_dir)}",
        "write_goog_output = true",
        "write_ascii_output = true",
        "write_farsite_atm = false",
    ]
        
    cfg_path.write_text("\n".join(lines), encoding="utf-8")

# %%
# --- hour folder (unchanged, just uses your mesh var) ---

def make_hour_folder(base_out: Path, dt_local) -> Path:
    """Folder name: Output_YYYY-MM-DD_HH00-HH50_Google earth_Fire_150m_10min"""
    start_str = dt_local.strftime("%Y-%m-%d_%H00")
    end_str = dt_local.strftime("%H50")
    name = f"Output_{start_str}-{end_str}_Google earth_Fire_{int(MESH_RES_M)}m_10min"
    path = base_out / name
    path.mkdir(parents=True, exist_ok=True)
    return path

# %%
def make_span_folder(base_out: Path, start_local, stop_local) -> Path:
    name = f"Output_{start_local:%Y-%m-%d_%H%M}-{stop_local:%H%M}_Google earth_Fire_{int(MESH_RES_M)}m_10min"
    path = base_out / name
    path.mkdir(parents=True, exist_ok=True)
    return path

# %%
def run_windninja(cfg_path: Path) -> str:
    """
    Execute WindNinja CLI with a direct full path.
    """
    if not WINDNINJA_CLI.exists():
        raise FileNotFoundError(f"WindNinja CLI not found at: {WINDNINJA_CLI}")

    cmd = [str(WINDNINJA_CLI), str(cfg_path)]

    # Run process, capture stdout/stderr
    result = subprocess.run(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        shell=False,
    )

    if result.returncode != 0:
        raise RuntimeError(
            f"WindNinja failed ({result.returncode}). Output:\n{result.stdout}"
        )

    return result.stdout

# %% [markdown]
# ## 3. Execute the program

# %%
def main():
    BASE_OUT.mkdir(parents=True, exist_ok=True)

    # Ensure exactly one CSV per station/day; do not overwrite existing
    day_folder, daily_csvs = ensure_daily_files(engine, BASE_OUT, START, END, VIEWS)

    # Station list for THIS day only
    station_list_csv = create_station_list_csv(day_folder, START, END)

    # Output folder for the simulation span
    out_folder = make_span_folder(BASE_OUT, START, END)
    out_folder.mkdir(parents=True, exist_ok=True)

    # Build cfg — pointInitialization using the list CSV
    cfg_path = out_folder / f"wn_ALL_{START:%Y%m%d_%H%M}-{END:%Y%m%d_%H%M}.cfg"
    build_cfg_point_init_span_cli(
        cfg_path,
        out_folder,
        station_list_csv,
        START,
        END,
        NR_TIMESTEPS
    )

    try:
        _ = run_windninja(cfg_path)
        print(f"ALL: WindNinja OK ({START:%Y-%m-%d %H:%M} → {END:%Y-%m-%d %H:%M}, {NR_TIMESTEPS} steps)")
    except Exception as e:
        print(f"ALL: WindNinja FAILED: {e}")
        try:
            print("--- CFG ---")
            print(cfg_path.read_text(encoding="utf-8"))
        except Exception:
            pass

    print("✅ Done.")

# %%
# THIS is only for one time period for an hour -> 6 timesteps!!!!

main()
# Out:
# ALL: WindNinja OK (2025-10-30 18:00 → 2025-10-30 20:50, 6 steps)
# ✅ Done.

# %% [markdown]
# #### 3.1 Parametrizing the main for multiple hour loops

# %%
def _ceil_to_hour(dt: datetime) -> datetime:
    if dt.minute == 0 and dt.second == 0 and dt.microsecond == 0:
        return dt
    return (dt.replace(minute=0, second=0, microsecond=0) + timedelta(hours=1))

# %%
def run_hourly(period_start: datetime,
               period_end: datetime,
               sim_minutes: int = 50,
               timezone: str = TIMEZONE):
    """
    Run the pipeline at every full hour within [period_start, period_end),
    with each simulation window being sim_minutes long (default 50 min).

    Example:
      period_start = 2025-08-31 08:00 Europe/Zurich
      period_end   = 2025-09-01 08:00 Europe/Zurich
      runs at: 08:00, 09:00, 10:00, ...; each END = START + 50 min (capped at period_end).
    """
    if period_start.tzinfo is None:
        period_start = period_start.replace(tzinfo=tz.gettz(timezone))
    if period_end.tzinfo is None:
        period_end = period_end.replace(tzinfo=tz.gettz(timezone))

    # Start at the next full hour at/after period_start
    cur = _ceil_to_hour(period_start)

    count = 0
    while cur < period_end:
        start_i = cur
        end_i = min(cur + timedelta(minutes=sim_minutes), period_end)
        if end_i <= start_i:
            break  # nothing to do (e.g., final partial window too short)

        print(f"\n⏱ Running window {count+1}: {start_i:%Y-%m-%d %H:%M} → {end_i:%H:%M}")
        main_for_window(start_i, end_i)

        cur += timedelta(hours=1)
        count += 1

    print(f"\n✅ Finished {count} hourly windows from {period_start:%Y-%m-%d %H:%M} to {period_end:%Y-%m-%d %H:%M}.")

# %%
def main_for_window(START, END):
    BASE_OUT.mkdir(parents=True, exist_ok=True)

    # Ensure exactly one CSV per station/day; do not overwrite existing
    day_folder, daily_csvs = ensure_daily_files(engine, BASE_OUT, START, END, VIEWS)

    # Station list for THIS day only
    station_list_csv = create_station_list_csv(day_folder, START, END)

    # Output folder for the simulation span
    out_folder = make_span_folder(BASE_OUT, START, END)
    out_folder.mkdir(parents=True, exist_ok=True)

    # Build cfg — pointInitialization using the list CSV
    cfg_path = out_folder / f"wn_ALL_{START:%Y%m%d_%H%M}-{END:%Y%m%d_%H%M}.cfg"
    build_cfg_point_init_span_cli(
        cfg_path,
        out_folder,
        station_list_csv,
        START,
        END,
        NR_TIMESTEPS
    )

    try:
        _ = run_windninja(cfg_path)
        print(f"ALL: WindNinja OK ({START:%Y-%m-%d %H:%M} → {END:%Y-%m-%d %H:%M}, {NR_TIMESTEPS} steps)")
    except Exception as e:
        print(f"ALL: WindNinja FAILED: {e}")
        try:
            print("--- CFG ---")
            print(cfg_path.read_text(encoding='utf-8'))
        except Exception:
            pass

    print("✅ Done window.")

# %%
# run the big loop over a bigger period of time

# User-specified overall period (can be one day or many)
period_start = datetime(2025, 8, 1, 0, 0, tzinfo=tz.gettz(TIMEZONE))
period_end   = datetime(2025, 8,  30, 23, 50, tzinfo=tz.gettz(TIMEZONE))

# Run per hour, each with a 50-minute simulation window
run_hourly(period_start, period_end, sim_minutes=50)
# Out:
# ⏱ Running window 1: 2025-08-01 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5015 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-01_0000-2025-08-01_0000-lake-thun/station_file_list_20250801.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 1
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 1
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-01_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 2: 2025-08-01 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5000 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-01_0000-2025-08-01_0000-lake-thun/station_file_list_20250801.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 1
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 1
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-01_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 3: 2025-08-01 02:00 → 02:50
# ALL: WindNinja OK (2025-08-01 02:00 → 2025-08-01 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 4: 2025-08-01 03:00 → 03:50
# ALL: WindNinja OK (2025-08-01 03:00 → 2025-08-01 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 5: 2025-08-01 04:00 → 04:50
# ALL: WindNinja OK (2025-08-01 04:00 → 2025-08-01 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 6: 2025-08-01 05:00 → 05:50
# ALL: WindNinja OK (2025-08-01 05:00 → 2025-08-01 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 7: 2025-08-01 06:00 → 06:50
# ALL: WindNinja OK (2025-08-01 06:00 → 2025-08-01 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 8: 2025-08-01 07:00 → 07:50
# ALL: WindNinja OK (2025-08-01 07:00 → 2025-08-01 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 9: 2025-08-01 08:00 → 08:50
# ALL: WindNinja OK (2025-08-01 08:00 → 2025-08-01 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 10: 2025-08-01 09:00 → 09:50
# ALL: WindNinja OK (2025-08-01 09:00 → 2025-08-01 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 11: 2025-08-01 10:00 → 10:50
# ALL: WindNinja OK (2025-08-01 10:00 → 2025-08-01 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 12: 2025-08-01 11:00 → 11:50
# ALL: WindNinja OK (2025-08-01 11:00 → 2025-08-01 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 13: 2025-08-01 12:00 → 12:50
# ALL: WindNinja OK (2025-08-01 12:00 → 2025-08-01 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 14: 2025-08-01 13:00 → 13:50
# ALL: WindNinja OK (2025-08-01 13:00 → 2025-08-01 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 15: 2025-08-01 14:00 → 14:50
# ALL: WindNinja OK (2025-08-01 14:00 → 2025-08-01 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 16: 2025-08-01 15:00 → 15:50
# ALL: WindNinja OK (2025-08-01 15:00 → 2025-08-01 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 17: 2025-08-01 16:00 → 16:50
# ALL: WindNinja OK (2025-08-01 16:00 → 2025-08-01 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 18: 2025-08-01 17:00 → 17:50
# ALL: WindNinja OK (2025-08-01 17:00 → 2025-08-01 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 19: 2025-08-01 18:00 → 18:50
# ALL: WindNinja OK (2025-08-01 18:00 → 2025-08-01 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 20: 2025-08-01 19:00 → 19:50
# ALL: WindNinja OK (2025-08-01 19:00 → 2025-08-01 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 21: 2025-08-01 20:00 → 20:50
# ALL: WindNinja OK (2025-08-01 20:00 → 2025-08-01 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 22: 2025-08-01 21:00 → 21:50
# ALL: WindNinja OK (2025-08-01 21:00 → 2025-08-01 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 23: 2025-08-01 22:00 → 22:50
# ALL: WindNinja OK (2025-08-01 22:00 → 2025-08-01 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 24: 2025-08-01 23:00 → 23:50
# ALL: WindNinja OK (2025-08-01 23:00 → 2025-08-01 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 25: 2025-08-02 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5000 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-02_0000-2025-08-02_0000-lake-thun/station_file_list_20250802.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 2
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 2
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-02_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 26: 2025-08-02 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5016 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-02_0000-2025-08-02_0000-lake-thun/station_file_list_20250802.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 2
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 2
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-02_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 27: 2025-08-02 02:00 → 02:50
# ALL: WindNinja OK (2025-08-02 02:00 → 2025-08-02 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 28: 2025-08-02 03:00 → 03:50
# ALL: WindNinja OK (2025-08-02 03:00 → 2025-08-02 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 29: 2025-08-02 04:00 → 04:50
# ALL: WindNinja OK (2025-08-02 04:00 → 2025-08-02 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 30: 2025-08-02 05:00 → 05:50
# ALL: WindNinja OK (2025-08-02 05:00 → 2025-08-02 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 31: 2025-08-02 06:00 → 06:50
# ALL: WindNinja OK (2025-08-02 06:00 → 2025-08-02 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 32: 2025-08-02 07:00 → 07:50
# ALL: WindNinja OK (2025-08-02 07:00 → 2025-08-02 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 33: 2025-08-02 08:00 → 08:50
# ALL: WindNinja OK (2025-08-02 08:00 → 2025-08-02 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 34: 2025-08-02 09:00 → 09:50
# ALL: WindNinja OK (2025-08-02 09:00 → 2025-08-02 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 35: 2025-08-02 10:00 → 10:50
# ALL: WindNinja OK (2025-08-02 10:00 → 2025-08-02 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 36: 2025-08-02 11:00 → 11:50
# ALL: WindNinja OK (2025-08-02 11:00 → 2025-08-02 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 37: 2025-08-02 12:00 → 12:50
# ALL: WindNinja OK (2025-08-02 12:00 → 2025-08-02 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 38: 2025-08-02 13:00 → 13:50
# ALL: WindNinja OK (2025-08-02 13:00 → 2025-08-02 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 39: 2025-08-02 14:00 → 14:50
# ALL: WindNinja OK (2025-08-02 14:00 → 2025-08-02 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 40: 2025-08-02 15:00 → 15:50
# ALL: WindNinja OK (2025-08-02 15:00 → 2025-08-02 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 41: 2025-08-02 16:00 → 16:50
# ALL: WindNinja OK (2025-08-02 16:00 → 2025-08-02 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 42: 2025-08-02 17:00 → 17:50
# ALL: WindNinja OK (2025-08-02 17:00 → 2025-08-02 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 43: 2025-08-02 18:00 → 18:50
# ALL: WindNinja OK (2025-08-02 18:00 → 2025-08-02 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 44: 2025-08-02 19:00 → 19:50
# ALL: WindNinja OK (2025-08-02 19:00 → 2025-08-02 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 45: 2025-08-02 20:00 → 20:50
# ALL: WindNinja OK (2025-08-02 20:00 → 2025-08-02 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 46: 2025-08-02 21:00 → 21:50
# ALL: WindNinja OK (2025-08-02 21:00 → 2025-08-02 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 47: 2025-08-02 22:00 → 22:50
# ALL: WindNinja OK (2025-08-02 22:00 → 2025-08-02 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 48: 2025-08-02 23:00 → 23:50
# ALL: WindNinja OK (2025-08-02 23:00 → 2025-08-02 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 49: 2025-08-03 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5016 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-03_0000-2025-08-03_0000-lake-thun/station_file_list_20250803.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 3
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 3
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-03_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 50: 2025-08-03 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5000 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-03_0000-2025-08-03_0000-lake-thun/station_file_list_20250803.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 3
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 3
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-03_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 51: 2025-08-03 02:00 → 02:50
# ALL: WindNinja OK (2025-08-03 02:00 → 2025-08-03 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 52: 2025-08-03 03:00 → 03:50
# ALL: WindNinja OK (2025-08-03 03:00 → 2025-08-03 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 53: 2025-08-03 04:00 → 04:50
# ALL: WindNinja OK (2025-08-03 04:00 → 2025-08-03 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 54: 2025-08-03 05:00 → 05:50
# ALL: WindNinja OK (2025-08-03 05:00 → 2025-08-03 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 55: 2025-08-03 06:00 → 06:50
# ALL: WindNinja OK (2025-08-03 06:00 → 2025-08-03 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 56: 2025-08-03 07:00 → 07:50
# ALL: WindNinja OK (2025-08-03 07:00 → 2025-08-03 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 57: 2025-08-03 08:00 → 08:50
# ALL: WindNinja OK (2025-08-03 08:00 → 2025-08-03 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 58: 2025-08-03 09:00 → 09:50
# ALL: WindNinja OK (2025-08-03 09:00 → 2025-08-03 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 59: 2025-08-03 10:00 → 10:50
# ALL: WindNinja OK (2025-08-03 10:00 → 2025-08-03 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 60: 2025-08-03 11:00 → 11:50
# ALL: WindNinja OK (2025-08-03 11:00 → 2025-08-03 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 61: 2025-08-03 12:00 → 12:50
# ALL: WindNinja OK (2025-08-03 12:00 → 2025-08-03 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 62: 2025-08-03 13:00 → 13:50
# ALL: WindNinja OK (2025-08-03 13:00 → 2025-08-03 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 63: 2025-08-03 14:00 → 14:50
# ALL: WindNinja OK (2025-08-03 14:00 → 2025-08-03 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 64: 2025-08-03 15:00 → 15:50
# ALL: WindNinja OK (2025-08-03 15:00 → 2025-08-03 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 65: 2025-08-03 16:00 → 16:50
# ALL: WindNinja OK (2025-08-03 16:00 → 2025-08-03 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 66: 2025-08-03 17:00 → 17:50
# ALL: WindNinja OK (2025-08-03 17:00 → 2025-08-03 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 67: 2025-08-03 18:00 → 18:50
# ALL: WindNinja OK (2025-08-03 18:00 → 2025-08-03 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 68: 2025-08-03 19:00 → 19:50
# ALL: WindNinja OK (2025-08-03 19:00 → 2025-08-03 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 69: 2025-08-03 20:00 → 20:50
# ALL: WindNinja OK (2025-08-03 20:00 → 2025-08-03 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 70: 2025-08-03 21:00 → 21:50
# ALL: WindNinja OK (2025-08-03 21:00 → 2025-08-03 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 71: 2025-08-03 22:00 → 22:50
# ALL: WindNinja OK (2025-08-03 22:00 → 2025-08-03 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 72: 2025-08-03 23:00 → 23:50
# ALL: WindNinja OK (2025-08-03 23:00 → 2025-08-03 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 73: 2025-08-04 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5000 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-04_0000-2025-08-04_0000-lake-thun/station_file_list_20250804.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 4
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 4
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-04_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 74: 2025-08-04 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5015 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-04_0000-2025-08-04_0000-lake-thun/station_file_list_20250804.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 4
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 4
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-04_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 75: 2025-08-04 02:00 → 02:50
# ALL: WindNinja OK (2025-08-04 02:00 → 2025-08-04 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 76: 2025-08-04 03:00 → 03:50
# ALL: WindNinja OK (2025-08-04 03:00 → 2025-08-04 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 77: 2025-08-04 04:00 → 04:50
# ALL: WindNinja OK (2025-08-04 04:00 → 2025-08-04 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 78: 2025-08-04 05:00 → 05:50
# ALL: WindNinja OK (2025-08-04 05:00 → 2025-08-04 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 79: 2025-08-04 06:00 → 06:50
# ALL: WindNinja OK (2025-08-04 06:00 → 2025-08-04 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 80: 2025-08-04 07:00 → 07:50
# ALL: WindNinja OK (2025-08-04 07:00 → 2025-08-04 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 81: 2025-08-04 08:00 → 08:50
# ALL: WindNinja OK (2025-08-04 08:00 → 2025-08-04 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 82: 2025-08-04 09:00 → 09:50
# ALL: WindNinja OK (2025-08-04 09:00 → 2025-08-04 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 83: 2025-08-04 10:00 → 10:50
# ALL: WindNinja OK (2025-08-04 10:00 → 2025-08-04 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 84: 2025-08-04 11:00 → 11:50
# ALL: WindNinja OK (2025-08-04 11:00 → 2025-08-04 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 85: 2025-08-04 12:00 → 12:50
# ALL: WindNinja OK (2025-08-04 12:00 → 2025-08-04 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 86: 2025-08-04 13:00 → 13:50
# ALL: WindNinja OK (2025-08-04 13:00 → 2025-08-04 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 87: 2025-08-04 14:00 → 14:50
# ALL: WindNinja OK (2025-08-04 14:00 → 2025-08-04 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 88: 2025-08-04 15:00 → 15:50
# ALL: WindNinja OK (2025-08-04 15:00 → 2025-08-04 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 89: 2025-08-04 16:00 → 16:50
# ALL: WindNinja OK (2025-08-04 16:00 → 2025-08-04 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 90: 2025-08-04 17:00 → 17:50
# ALL: WindNinja OK (2025-08-04 17:00 → 2025-08-04 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 91: 2025-08-04 18:00 → 18:50
# ALL: WindNinja OK (2025-08-04 18:00 → 2025-08-04 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 92: 2025-08-04 19:00 → 19:50
# ALL: WindNinja OK (2025-08-04 19:00 → 2025-08-04 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 93: 2025-08-04 20:00 → 20:50
# ALL: WindNinja OK (2025-08-04 20:00 → 2025-08-04 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 94: 2025-08-04 21:00 → 21:50
# ALL: WindNinja OK (2025-08-04 21:00 → 2025-08-04 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 95: 2025-08-04 22:00 → 22:50
# ALL: WindNinja OK (2025-08-04 22:00 → 2025-08-04 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 96: 2025-08-04 23:00 → 23:50
# ALL: WindNinja OK (2025-08-04 23:00 → 2025-08-04 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 97: 2025-08-05 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5015 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-05_0000-2025-08-05_0000-lake-thun/station_file_list_20250805.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 5
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 5
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-05_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 98: 2025-08-05 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5016 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-05_0000-2025-08-05_0000-lake-thun/station_file_list_20250805.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 5
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 5
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-05_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 99: 2025-08-05 02:00 → 02:50
# ALL: WindNinja OK (2025-08-05 02:00 → 2025-08-05 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 100: 2025-08-05 03:00 → 03:50
# ALL: WindNinja OK (2025-08-05 03:00 → 2025-08-05 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 101: 2025-08-05 04:00 → 04:50
# ALL: WindNinja OK (2025-08-05 04:00 → 2025-08-05 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 102: 2025-08-05 05:00 → 05:50
# ALL: WindNinja OK (2025-08-05 05:00 → 2025-08-05 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 103: 2025-08-05 06:00 → 06:50
# ALL: WindNinja OK (2025-08-05 06:00 → 2025-08-05 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 104: 2025-08-05 07:00 → 07:50
# ALL: WindNinja OK (2025-08-05 07:00 → 2025-08-05 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 105: 2025-08-05 08:00 → 08:50
# ALL: WindNinja OK (2025-08-05 08:00 → 2025-08-05 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 106: 2025-08-05 09:00 → 09:50
# ALL: WindNinja OK (2025-08-05 09:00 → 2025-08-05 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 107: 2025-08-05 10:00 → 10:50
# ALL: WindNinja OK (2025-08-05 10:00 → 2025-08-05 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 108: 2025-08-05 11:00 → 11:50
# ALL: WindNinja OK (2025-08-05 11:00 → 2025-08-05 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 109: 2025-08-05 12:00 → 12:50
# ALL: WindNinja OK (2025-08-05 12:00 → 2025-08-05 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 110: 2025-08-05 13:00 → 13:50
# ALL: WindNinja OK (2025-08-05 13:00 → 2025-08-05 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 111: 2025-08-05 14:00 → 14:50
# ALL: WindNinja OK (2025-08-05 14:00 → 2025-08-05 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 112: 2025-08-05 15:00 → 15:50
# ALL: WindNinja OK (2025-08-05 15:00 → 2025-08-05 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 113: 2025-08-05 16:00 → 16:50
# ALL: WindNinja OK (2025-08-05 16:00 → 2025-08-05 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 114: 2025-08-05 17:00 → 17:50
# ALL: WindNinja OK (2025-08-05 17:00 → 2025-08-05 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 115: 2025-08-05 18:00 → 18:50
# ALL: WindNinja OK (2025-08-05 18:00 → 2025-08-05 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 116: 2025-08-05 19:00 → 19:50
# ALL: WindNinja OK (2025-08-05 19:00 → 2025-08-05 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 117: 2025-08-05 20:00 → 20:50
# ALL: WindNinja OK (2025-08-05 20:00 → 2025-08-05 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 118: 2025-08-05 21:00 → 21:50
# ALL: WindNinja OK (2025-08-05 21:00 → 2025-08-05 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 119: 2025-08-05 22:00 → 22:50
# ALL: WindNinja OK (2025-08-05 22:00 → 2025-08-05 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 120: 2025-08-05 23:00 → 23:50
# ALL: WindNinja OK (2025-08-05 23:00 → 2025-08-05 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 121: 2025-08-06 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5000 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-06_0000-2025-08-06_0000-lake-thun/station_file_list_20250806.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 6
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 6
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-06_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 122: 2025-08-06 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# ERROR 1: Connection timed out after 5015 milliseconds
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-06_0000-2025-08-06_0000-lake-thun/station_file_list_20250806.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 6
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 6
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-06_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 123: 2025-08-06 02:00 → 02:50
# ALL: WindNinja OK (2025-08-06 02:00 → 2025-08-06 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 124: 2025-08-06 03:00 → 03:50
# ALL: WindNinja OK (2025-08-06 03:00 → 2025-08-06 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 125: 2025-08-06 04:00 → 04:50
# ALL: WindNinja OK (2025-08-06 04:00 → 2025-08-06 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 126: 2025-08-06 05:00 → 05:50
# ALL: WindNinja OK (2025-08-06 05:00 → 2025-08-06 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 127: 2025-08-06 06:00 → 06:50
# ALL: WindNinja OK (2025-08-06 06:00 → 2025-08-06 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 128: 2025-08-06 07:00 → 07:50
# ALL: WindNinja OK (2025-08-06 07:00 → 2025-08-06 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 129: 2025-08-06 08:00 → 08:50
# ALL: WindNinja OK (2025-08-06 08:00 → 2025-08-06 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 130: 2025-08-06 09:00 → 09:50
# ALL: WindNinja OK (2025-08-06 09:00 → 2025-08-06 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 131: 2025-08-06 10:00 → 10:50
# ALL: WindNinja OK (2025-08-06 10:00 → 2025-08-06 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 132: 2025-08-06 11:00 → 11:50
# ALL: WindNinja OK (2025-08-06 11:00 → 2025-08-06 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 133: 2025-08-06 12:00 → 12:50
# ALL: WindNinja OK (2025-08-06 12:00 → 2025-08-06 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 134: 2025-08-06 13:00 → 13:50
# ALL: WindNinja OK (2025-08-06 13:00 → 2025-08-06 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 135: 2025-08-06 14:00 → 14:50
# ALL: WindNinja OK (2025-08-06 14:00 → 2025-08-06 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 136: 2025-08-06 15:00 → 15:50
# ALL: WindNinja OK (2025-08-06 15:00 → 2025-08-06 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 137: 2025-08-06 16:00 → 16:50
# ALL: WindNinja OK (2025-08-06 16:00 → 2025-08-06 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 138: 2025-08-06 17:00 → 17:50
# ALL: WindNinja OK (2025-08-06 17:00 → 2025-08-06 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 139: 2025-08-06 18:00 → 18:50
# ALL: WindNinja OK (2025-08-06 18:00 → 2025-08-06 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 140: 2025-08-06 19:00 → 19:50
# ALL: WindNinja OK (2025-08-06 19:00 → 2025-08-06 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 141: 2025-08-06 20:00 → 20:50
# ALL: WindNinja OK (2025-08-06 20:00 → 2025-08-06 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 142: 2025-08-06 21:00 → 21:50
# ALL: WindNinja OK (2025-08-06 21:00 → 2025-08-06 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 143: 2025-08-06 22:00 → 22:50
# ALL: WindNinja OK (2025-08-06 22:00 → 2025-08-06 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 144: 2025-08-06 23:00 → 23:50
# ALL: WindNinja OK (2025-08-06 23:00 → 2025-08-06 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 145: 2025-08-07 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-07_0000-2025-08-07_0000-lake-thun/station_file_list_20250807.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 7
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 7
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-07_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 146: 2025-08-07 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-07_0000-2025-08-07_0000-lake-thun/station_file_list_20250807.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 7
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 7
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-07_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 147: 2025-08-07 02:00 → 02:50
# ALL: WindNinja OK (2025-08-07 02:00 → 2025-08-07 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 148: 2025-08-07 03:00 → 03:50
# ALL: WindNinja OK (2025-08-07 03:00 → 2025-08-07 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 149: 2025-08-07 04:00 → 04:50
# ALL: WindNinja OK (2025-08-07 04:00 → 2025-08-07 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 150: 2025-08-07 05:00 → 05:50
# ALL: WindNinja OK (2025-08-07 05:00 → 2025-08-07 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 151: 2025-08-07 06:00 → 06:50
# ALL: WindNinja OK (2025-08-07 06:00 → 2025-08-07 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 152: 2025-08-07 07:00 → 07:50
# ALL: WindNinja OK (2025-08-07 07:00 → 2025-08-07 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 153: 2025-08-07 08:00 → 08:50
# ALL: WindNinja OK (2025-08-07 08:00 → 2025-08-07 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 154: 2025-08-07 09:00 → 09:50
# ALL: WindNinja OK (2025-08-07 09:00 → 2025-08-07 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 155: 2025-08-07 10:00 → 10:50
# ALL: WindNinja OK (2025-08-07 10:00 → 2025-08-07 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 156: 2025-08-07 11:00 → 11:50
# ALL: WindNinja OK (2025-08-07 11:00 → 2025-08-07 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 157: 2025-08-07 12:00 → 12:50
# ALL: WindNinja OK (2025-08-07 12:00 → 2025-08-07 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 158: 2025-08-07 13:00 → 13:50
# ALL: WindNinja OK (2025-08-07 13:00 → 2025-08-07 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 159: 2025-08-07 14:00 → 14:50
# ALL: WindNinja OK (2025-08-07 14:00 → 2025-08-07 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 160: 2025-08-07 15:00 → 15:50
# ALL: WindNinja OK (2025-08-07 15:00 → 2025-08-07 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 161: 2025-08-07 16:00 → 16:50
# ALL: WindNinja OK (2025-08-07 16:00 → 2025-08-07 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 162: 2025-08-07 17:00 → 17:50
# ALL: WindNinja OK (2025-08-07 17:00 → 2025-08-07 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 163: 2025-08-07 18:00 → 18:50
# ALL: WindNinja OK (2025-08-07 18:00 → 2025-08-07 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 164: 2025-08-07 19:00 → 19:50
# ALL: WindNinja OK (2025-08-07 19:00 → 2025-08-07 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 165: 2025-08-07 20:00 → 20:50
# ALL: WindNinja OK (2025-08-07 20:00 → 2025-08-07 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 166: 2025-08-07 21:00 → 21:50
# ALL: WindNinja OK (2025-08-07 21:00 → 2025-08-07 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 167: 2025-08-07 22:00 → 22:50
# ALL: WindNinja OK (2025-08-07 22:00 → 2025-08-07 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 168: 2025-08-07 23:00 → 23:50
# ALL: WindNinja OK (2025-08-07 23:00 → 2025-08-07 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 169: 2025-08-08 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-08_0000-2025-08-08_0000-lake-thun/station_file_list_20250808.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 8
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 8
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-08_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 170: 2025-08-08 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-08_0000-2025-08-08_0000-lake-thun/station_file_list_20250808.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 8
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 8
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-08_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 171: 2025-08-08 02:00 → 02:50
# ALL: WindNinja OK (2025-08-08 02:00 → 2025-08-08 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 172: 2025-08-08 03:00 → 03:50
# ALL: WindNinja OK (2025-08-08 03:00 → 2025-08-08 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 173: 2025-08-08 04:00 → 04:50
# ALL: WindNinja OK (2025-08-08 04:00 → 2025-08-08 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 174: 2025-08-08 05:00 → 05:50
# ALL: WindNinja OK (2025-08-08 05:00 → 2025-08-08 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 175: 2025-08-08 06:00 → 06:50
# ALL: WindNinja OK (2025-08-08 06:00 → 2025-08-08 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 176: 2025-08-08 07:00 → 07:50
# ALL: WindNinja OK (2025-08-08 07:00 → 2025-08-08 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 177: 2025-08-08 08:00 → 08:50
# ALL: WindNinja OK (2025-08-08 08:00 → 2025-08-08 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 178: 2025-08-08 09:00 → 09:50
# ALL: WindNinja OK (2025-08-08 09:00 → 2025-08-08 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 179: 2025-08-08 10:00 → 10:50
# ALL: WindNinja OK (2025-08-08 10:00 → 2025-08-08 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 180: 2025-08-08 11:00 → 11:50
# ALL: WindNinja OK (2025-08-08 11:00 → 2025-08-08 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 181: 2025-08-08 12:00 → 12:50
# ALL: WindNinja OK (2025-08-08 12:00 → 2025-08-08 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 182: 2025-08-08 13:00 → 13:50
# ALL: WindNinja OK (2025-08-08 13:00 → 2025-08-08 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 183: 2025-08-08 14:00 → 14:50
# ALL: WindNinja OK (2025-08-08 14:00 → 2025-08-08 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 184: 2025-08-08 15:00 → 15:50
# ALL: WindNinja OK (2025-08-08 15:00 → 2025-08-08 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 185: 2025-08-08 16:00 → 16:50
# ALL: WindNinja OK (2025-08-08 16:00 → 2025-08-08 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 186: 2025-08-08 17:00 → 17:50
# ALL: WindNinja OK (2025-08-08 17:00 → 2025-08-08 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 187: 2025-08-08 18:00 → 18:50
# ALL: WindNinja OK (2025-08-08 18:00 → 2025-08-08 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 188: 2025-08-08 19:00 → 19:50
# ALL: WindNinja OK (2025-08-08 19:00 → 2025-08-08 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 189: 2025-08-08 20:00 → 20:50
# ALL: WindNinja OK (2025-08-08 20:00 → 2025-08-08 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 190: 2025-08-08 21:00 → 21:50
# ALL: WindNinja OK (2025-08-08 21:00 → 2025-08-08 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 191: 2025-08-08 22:00 → 22:50
# ALL: WindNinja OK (2025-08-08 22:00 → 2025-08-08 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 192: 2025-08-08 23:00 → 23:50
# ALL: WindNinja OK (2025-08-08 23:00 → 2025-08-08 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 193: 2025-08-09 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-09_0000-2025-08-09_0000-lake-thun/station_file_list_20250809.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 9
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 9
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-09_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 194: 2025-08-09 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-09_0000-2025-08-09_0000-lake-thun/station_file_list_20250809.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 9
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 9
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-09_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 195: 2025-08-09 02:00 → 02:50
# ALL: WindNinja OK (2025-08-09 02:00 → 2025-08-09 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 196: 2025-08-09 03:00 → 03:50
# ALL: WindNinja OK (2025-08-09 03:00 → 2025-08-09 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 197: 2025-08-09 04:00 → 04:50
# ALL: WindNinja OK (2025-08-09 04:00 → 2025-08-09 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 198: 2025-08-09 05:00 → 05:50
# ALL: WindNinja OK (2025-08-09 05:00 → 2025-08-09 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 199: 2025-08-09 06:00 → 06:50
# ALL: WindNinja OK (2025-08-09 06:00 → 2025-08-09 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 200: 2025-08-09 07:00 → 07:50
# ALL: WindNinja OK (2025-08-09 07:00 → 2025-08-09 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 201: 2025-08-09 08:00 → 08:50
# ALL: WindNinja OK (2025-08-09 08:00 → 2025-08-09 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 202: 2025-08-09 09:00 → 09:50
# ALL: WindNinja OK (2025-08-09 09:00 → 2025-08-09 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 203: 2025-08-09 10:00 → 10:50
# ALL: WindNinja OK (2025-08-09 10:00 → 2025-08-09 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 204: 2025-08-09 11:00 → 11:50
# ALL: WindNinja OK (2025-08-09 11:00 → 2025-08-09 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 205: 2025-08-09 12:00 → 12:50
# ALL: WindNinja OK (2025-08-09 12:00 → 2025-08-09 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 206: 2025-08-09 13:00 → 13:50
# ALL: WindNinja OK (2025-08-09 13:00 → 2025-08-09 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 207: 2025-08-09 14:00 → 14:50
# ALL: WindNinja OK (2025-08-09 14:00 → 2025-08-09 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 208: 2025-08-09 15:00 → 15:50
# ALL: WindNinja OK (2025-08-09 15:00 → 2025-08-09 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 209: 2025-08-09 16:00 → 16:50
# ALL: WindNinja OK (2025-08-09 16:00 → 2025-08-09 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 210: 2025-08-09 17:00 → 17:50
# ALL: WindNinja OK (2025-08-09 17:00 → 2025-08-09 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 211: 2025-08-09 18:00 → 18:50
# ALL: WindNinja OK (2025-08-09 18:00 → 2025-08-09 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 212: 2025-08-09 19:00 → 19:50
# ALL: WindNinja OK (2025-08-09 19:00 → 2025-08-09 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 213: 2025-08-09 20:00 → 20:50
# ALL: WindNinja OK (2025-08-09 20:00 → 2025-08-09 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 214: 2025-08-09 21:00 → 21:50
# ALL: WindNinja OK (2025-08-09 21:00 → 2025-08-09 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 215: 2025-08-09 22:00 → 22:50
# ALL: WindNinja OK (2025-08-09 22:00 → 2025-08-09 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 216: 2025-08-09 23:00 → 23:50
# ALL: WindNinja OK (2025-08-09 23:00 → 2025-08-09 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 217: 2025-08-10 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-10_0000-2025-08-10_0000-lake-thun/station_file_list_20250810.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 10
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 10
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-10_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 218: 2025-08-10 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-10_0000-2025-08-10_0000-lake-thun/station_file_list_20250810.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 10
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 10
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-10_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 219: 2025-08-10 02:00 → 02:50
# ALL: WindNinja OK (2025-08-10 02:00 → 2025-08-10 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 220: 2025-08-10 03:00 → 03:50
# ALL: WindNinja OK (2025-08-10 03:00 → 2025-08-10 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 221: 2025-08-10 04:00 → 04:50
# ALL: WindNinja OK (2025-08-10 04:00 → 2025-08-10 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 222: 2025-08-10 05:00 → 05:50
# ALL: WindNinja OK (2025-08-10 05:00 → 2025-08-10 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 223: 2025-08-10 06:00 → 06:50
# ALL: WindNinja OK (2025-08-10 06:00 → 2025-08-10 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 224: 2025-08-10 07:00 → 07:50
# ALL: WindNinja OK (2025-08-10 07:00 → 2025-08-10 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 225: 2025-08-10 08:00 → 08:50
# ALL: WindNinja OK (2025-08-10 08:00 → 2025-08-10 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 226: 2025-08-10 09:00 → 09:50
# ...
# ALL: WindNinja OK (2025-08-27 15:00 → 2025-08-27 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 641: 2025-08-27 16:00 → 16:50
# ALL: WindNinja OK (2025-08-27 16:00 → 2025-08-27 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 642: 2025-08-27 17:00 → 17:50
# ALL: WindNinja OK (2025-08-27 17:00 → 2025-08-27 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 643: 2025-08-27 18:00 → 18:50
# ALL: WindNinja OK (2025-08-27 18:00 → 2025-08-27 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 644: 2025-08-27 19:00 → 19:50
# ALL: WindNinja OK (2025-08-27 19:00 → 2025-08-27 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 645: 2025-08-27 20:00 → 20:50
# ALL: WindNinja OK (2025-08-27 20:00 → 2025-08-27 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 646: 2025-08-27 21:00 → 21:50
# ALL: WindNinja OK (2025-08-27 21:00 → 2025-08-27 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 647: 2025-08-27 22:00 → 22:50
# ALL: WindNinja OK (2025-08-27 22:00 → 2025-08-27 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 648: 2025-08-27 23:00 → 23:50
# ALL: WindNinja OK (2025-08-27 23:00 → 2025-08-27 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 649: 2025-08-28 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-28_0000-2025-08-28_0000-lake-thun/station_file_list_20250828.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 28
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 28
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-28_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 650: 2025-08-28 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-28_0000-2025-08-28_0000-lake-thun/station_file_list_20250828.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 28
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 28
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-28_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 651: 2025-08-28 02:00 → 02:50
# ALL: WindNinja OK (2025-08-28 02:00 → 2025-08-28 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 652: 2025-08-28 03:00 → 03:50
# ALL: WindNinja OK (2025-08-28 03:00 → 2025-08-28 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 653: 2025-08-28 04:00 → 04:50
# ALL: WindNinja OK (2025-08-28 04:00 → 2025-08-28 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 654: 2025-08-28 05:00 → 05:50
# ALL: WindNinja OK (2025-08-28 05:00 → 2025-08-28 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 655: 2025-08-28 06:00 → 06:50
# ALL: WindNinja OK (2025-08-28 06:00 → 2025-08-28 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 656: 2025-08-28 07:00 → 07:50
# ALL: WindNinja OK (2025-08-28 07:00 → 2025-08-28 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 657: 2025-08-28 08:00 → 08:50
# ALL: WindNinja OK (2025-08-28 08:00 → 2025-08-28 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 658: 2025-08-28 09:00 → 09:50
# ALL: WindNinja OK (2025-08-28 09:00 → 2025-08-28 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 659: 2025-08-28 10:00 → 10:50
# ALL: WindNinja OK (2025-08-28 10:00 → 2025-08-28 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 660: 2025-08-28 11:00 → 11:50
# ALL: WindNinja OK (2025-08-28 11:00 → 2025-08-28 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 661: 2025-08-28 12:00 → 12:50
# ALL: WindNinja OK (2025-08-28 12:00 → 2025-08-28 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 662: 2025-08-28 13:00 → 13:50
# ALL: WindNinja OK (2025-08-28 13:00 → 2025-08-28 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 663: 2025-08-28 14:00 → 14:50
# ALL: WindNinja OK (2025-08-28 14:00 → 2025-08-28 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 664: 2025-08-28 15:00 → 15:50
# ALL: WindNinja OK (2025-08-28 15:00 → 2025-08-28 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 665: 2025-08-28 16:00 → 16:50
# ALL: WindNinja OK (2025-08-28 16:00 → 2025-08-28 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 666: 2025-08-28 17:00 → 17:50
# ALL: WindNinja OK (2025-08-28 17:00 → 2025-08-28 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 667: 2025-08-28 18:00 → 18:50
# ALL: WindNinja OK (2025-08-28 18:00 → 2025-08-28 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 668: 2025-08-28 19:00 → 19:50
# ALL: WindNinja OK (2025-08-28 19:00 → 2025-08-28 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 669: 2025-08-28 20:00 → 20:50
# ALL: WindNinja OK (2025-08-28 20:00 → 2025-08-28 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 670: 2025-08-28 21:00 → 21:50
# ALL: WindNinja OK (2025-08-28 21:00 → 2025-08-28 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 671: 2025-08-28 22:00 → 22:50
# ALL: WindNinja OK (2025-08-28 22:00 → 2025-08-28 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 672: 2025-08-28 23:00 → 23:50
# ALL: WindNinja OK (2025-08-28 23:00 → 2025-08-28 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 673: 2025-08-29 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-29_0000-2025-08-29_0000-lake-thun/station_file_list_20250829.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 29
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 29
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-29_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 674: 2025-08-29 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-29_0000-2025-08-29_0000-lake-thun/station_file_list_20250829.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 29
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 29
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-29_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 675: 2025-08-29 02:00 → 02:50
# ALL: WindNinja OK (2025-08-29 02:00 → 2025-08-29 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 676: 2025-08-29 03:00 → 03:50
# ALL: WindNinja OK (2025-08-29 03:00 → 2025-08-29 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 677: 2025-08-29 04:00 → 04:50
# ALL: WindNinja OK (2025-08-29 04:00 → 2025-08-29 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 678: 2025-08-29 05:00 → 05:50
# ALL: WindNinja OK (2025-08-29 05:00 → 2025-08-29 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 679: 2025-08-29 06:00 → 06:50
# ALL: WindNinja OK (2025-08-29 06:00 → 2025-08-29 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 680: 2025-08-29 07:00 → 07:50
# ALL: WindNinja OK (2025-08-29 07:00 → 2025-08-29 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 681: 2025-08-29 08:00 → 08:50
# ALL: WindNinja OK (2025-08-29 08:00 → 2025-08-29 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 682: 2025-08-29 09:00 → 09:50
# ALL: WindNinja OK (2025-08-29 09:00 → 2025-08-29 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 683: 2025-08-29 10:00 → 10:50
# ALL: WindNinja OK (2025-08-29 10:00 → 2025-08-29 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 684: 2025-08-29 11:00 → 11:50
# ALL: WindNinja OK (2025-08-29 11:00 → 2025-08-29 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 685: 2025-08-29 12:00 → 12:50
# ALL: WindNinja OK (2025-08-29 12:00 → 2025-08-29 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 686: 2025-08-29 13:00 → 13:50
# ALL: WindNinja OK (2025-08-29 13:00 → 2025-08-29 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 687: 2025-08-29 14:00 → 14:50
# ALL: WindNinja OK (2025-08-29 14:00 → 2025-08-29 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 688: 2025-08-29 15:00 → 15:50
# ALL: WindNinja OK (2025-08-29 15:00 → 2025-08-29 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 689: 2025-08-29 16:00 → 16:50
# ALL: WindNinja OK (2025-08-29 16:00 → 2025-08-29 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 690: 2025-08-29 17:00 → 17:50
# ALL: WindNinja OK (2025-08-29 17:00 → 2025-08-29 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 691: 2025-08-29 18:00 → 18:50
# ALL: WindNinja OK (2025-08-29 18:00 → 2025-08-29 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 692: 2025-08-29 19:00 → 19:50
# ALL: WindNinja OK (2025-08-29 19:00 → 2025-08-29 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 693: 2025-08-29 20:00 → 20:50
# ALL: WindNinja OK (2025-08-29 20:00 → 2025-08-29 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 694: 2025-08-29 21:00 → 21:50
# ALL: WindNinja OK (2025-08-29 21:00 → 2025-08-29 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 695: 2025-08-29 22:00 → 22:50
# ALL: WindNinja OK (2025-08-29 22:00 → 2025-08-29 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 696: 2025-08-29 23:00 → 23:50
# ALL: WindNinja OK (2025-08-29 23:00 → 2025-08-29 23:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 697: 2025-08-30 00:00 → 00:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-30_0000-2025-08-30_0000-lake-thun/station_file_list_20250830.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 30
# start_hour = 0
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 30
# stop_hour = 0
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-30_0000-0050_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 698: 2025-08-30 01:00 → 01:50
# ALL: WindNinja FAILED: WindNinja failed (4294967295). Output:
# Exception caught: USER PROVIDED START TIME IS OUTSIDE DATASET TIME SPAN!! Provided start time < dataset start time for all wx stations!
#
# --- CFG ---
# num_threads = 8
# elevation_file = merlingen_7.5mi.tif
# initialization_method = pointInitialization
# wx_station_filename = windninja_output/WXSTATIONS-CET-2025-08-30_0000-2025-08-30_0000-lake-thun/station_file_list_20250830.csv
# match_points = true
# number_time_steps = 6
# start_year = 2025
# start_month = 8
# start_day = 30
# start_hour = 1
# start_minute = 0
# stop_year = 2025
# stop_month = 8
# stop_day = 30
# stop_hour = 1
# stop_minute = 50
# time_zone = Europe/Zurich
# vegetation = trees
# diurnal_winds = false
# mesh_resolution = 150
# units_mesh_resolution = m
# output_wind_height = 10.0
# units_output_wind_height = m
# output_speed_units = mps
# output_path = windninja_output/Output_2025-08-30_0100-0150_Google earth_Fire_150m_10min
# write_goog_output = true
# write_ascii_output = true
# write_farsite_atm = false
# ✅ Done window.
#
# ⏱ Running window 699: 2025-08-30 02:00 → 02:50
# ALL: WindNinja OK (2025-08-30 02:00 → 2025-08-30 02:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 700: 2025-08-30 03:00 → 03:50
# ALL: WindNinja OK (2025-08-30 03:00 → 2025-08-30 03:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 701: 2025-08-30 04:00 → 04:50
# ALL: WindNinja OK (2025-08-30 04:00 → 2025-08-30 04:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 702: 2025-08-30 05:00 → 05:50
# ALL: WindNinja OK (2025-08-30 05:00 → 2025-08-30 05:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 703: 2025-08-30 06:00 → 06:50
# ALL: WindNinja OK (2025-08-30 06:00 → 2025-08-30 06:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 704: 2025-08-30 07:00 → 07:50
# ALL: WindNinja OK (2025-08-30 07:00 → 2025-08-30 07:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 705: 2025-08-30 08:00 → 08:50
# ALL: WindNinja OK (2025-08-30 08:00 → 2025-08-30 08:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 706: 2025-08-30 09:00 → 09:50
# ALL: WindNinja OK (2025-08-30 09:00 → 2025-08-30 09:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 707: 2025-08-30 10:00 → 10:50
# ALL: WindNinja OK (2025-08-30 10:00 → 2025-08-30 10:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 708: 2025-08-30 11:00 → 11:50
# ALL: WindNinja OK (2025-08-30 11:00 → 2025-08-30 11:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 709: 2025-08-30 12:00 → 12:50
# ALL: WindNinja OK (2025-08-30 12:00 → 2025-08-30 12:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 710: 2025-08-30 13:00 → 13:50
# ALL: WindNinja OK (2025-08-30 13:00 → 2025-08-30 13:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 711: 2025-08-30 14:00 → 14:50
# ALL: WindNinja OK (2025-08-30 14:00 → 2025-08-30 14:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 712: 2025-08-30 15:00 → 15:50
# ALL: WindNinja OK (2025-08-30 15:00 → 2025-08-30 15:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 713: 2025-08-30 16:00 → 16:50
# ALL: WindNinja OK (2025-08-30 16:00 → 2025-08-30 16:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 714: 2025-08-30 17:00 → 17:50
# ALL: WindNinja OK (2025-08-30 17:00 → 2025-08-30 17:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 715: 2025-08-30 18:00 → 18:50
# ALL: WindNinja OK (2025-08-30 18:00 → 2025-08-30 18:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 716: 2025-08-30 19:00 → 19:50
# ALL: WindNinja OK (2025-08-30 19:00 → 2025-08-30 19:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 717: 2025-08-30 20:00 → 20:50
# ALL: WindNinja OK (2025-08-30 20:00 → 2025-08-30 20:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 718: 2025-08-30 21:00 → 21:50
# ALL: WindNinja OK (2025-08-30 21:00 → 2025-08-30 21:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 719: 2025-08-30 22:00 → 22:50
# ALL: WindNinja OK (2025-08-30 22:00 → 2025-08-30 22:50, 6 steps)
# ✅ Done window.
#
# ⏱ Running window 720: 2025-08-30 23:00 → 23:50
# ALL: WindNinja OK (2025-08-30 23:00 → 2025-08-30 23:50, 6 steps)
# ✅ Done window.
#
# ✅ Finished 720 hourly windows from 2025-08-01 00:00 to 2025-08-30 23:50.

# %% [markdown]
# ## 4. Test and compare windoutputs with GUI outputs

# %%
from pathlib import Path
import re
import numpy as np
import pandas as pd

# %%
def compare_windninja_outputs(GUI_DIR: Path, CLI_DIR: Path, tolerance_pct: float = 1.0):
    """
    Compare outputs (KMZ, .ang.asc, .vel.asc) between GUI and CLI runs.
    
    Returns a DataFrame with:
      - filename_gui
      - filename_cli
      - same_output (True/False)
      - diff_pct (mean absolute % difference if numeric)
    
    Notes:
      - KMZ: compares ZIP content hashes (not unzipped rasters).
      - .asc: compares numeric grids after parsing to numpy arrays.
    """
    def read_asc_values(path: Path):
        """Read ASCII grid (.asc) file into numpy array of floats."""
        with open(path, "r", encoding="utf-8") as f:
            lines = f.readlines()
        # Skip header lines starting with known keywords
        data = []
        for line in lines:
            if any(line.lower().startswith(k) for k in ["ncols", "nrows", "xllcorner", "yllcorner", "cellsize", "nodata_value"]):
                continue
            vals = line.strip().split()
            if vals:
                data.extend(map(float, vals))
        return np.array(data)

    def compare_asc(gui_path: Path, cli_path: Path):
        """Compare two ASCII grids, return % difference."""
        a = read_asc_values(gui_path)
        b = read_asc_values(cli_path)
        if a.shape != b.shape:
            return np.nan
        # mean absolute percent difference ignoring zeros
        mask = (a != 0)
        if not mask.any():
            return 0.0
        diff_pct = np.mean(np.abs(a[mask] - b[mask]) / np.abs(a[mask])) * 100
        return diff_pct

    def compare_kmz(gui_path: Path, cli_path: Path):
        """Compare KMZ (zip) content by file list + CRCs."""
        try:
            with zipfile.ZipFile(gui_path, "r") as g, zipfile.ZipFile(cli_path, "r") as c:
                g_info = sorted([(x.filename, x.CRC) for x in g.infolist()])
                c_info = sorted([(x.filename, x.CRC) for x in c.infolist()])
                return g_info == c_info
        except Exception:
            return False

    results = []

    for gui_file in GUI_DIR.glob("**/*"):
        if not gui_file.is_file():
            continue

        rel = gui_file.relative_to(GUI_DIR)
        cli_file = CLI_DIR / rel

        if not cli_file.exists():
            results.append({
                "filename_gui": str(gui_file),
                "filename_cli": str(cli_file),
                "same_output": False,
                "diff_pct": np.nan
            })
            continue

        # Determine comparison type
        if gui_file.suffix.lower() == ".kmz":
            same = compare_kmz(gui_file, cli_file)
            diff = 0.0 if same else np.nan
        elif gui_file.suffix.lower().endswith(".asc"):
            diff = compare_asc(gui_file, cli_file)
            same = diff <= tolerance_pct
        else:
            # unknown file type, do binary compare
            same = gui_file.read_bytes() == cli_file.read_bytes()
            diff = 0.0 if same else np.nan

        results.append({
            "filename_gui": str(gui_file),
            "filename_cli": str(cli_file),
            "same_output": bool(same),
            "diff_pct": round(diff, 3) if diff is not None else np.nan
        })

    df = pd.DataFrame(results)
    return df

# %%
# === USER INPUT: point these to your *hour* folders (or parent dirs) ===
GUI_DIR = Path(r"C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min")
CLI_DIR = Path(r"C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min")

# %%
pd.set_option("display.max_colwidth", None)  # show full content, no truncation
pd.set_option("display.expand_frame_repr", False)  # prevent line wrapping
pd.set_option("display.max_columns", None)  # show all columns



df_cmp = compare_windninja_outputs(GUI_DIR, CLI_DIR, tolerance_pct=1.0)
display(df_cmp)
# Out:
#                                                                                                                                                                                                     filename_gui                                                                                                                                                                                   filename_cli  same_output  diff_pct
# 0               C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m.kmz        False       NaN
# 1           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.asc         True       0.0
# 2   C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.asc.aux.xml        False       NaN
# 3           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_ang.prj         True       0.0
# 4           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_cld.asc        False     100.0
# 5           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_cld.prj         True       0.0
# 6           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.asc         True       0.0
# 7   C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.asc.aux.xml        False       NaN
# 8           C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0600_150m_vel.prj         True       0.0
# 9               C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m.kmz        False       NaN
# 10          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.asc         True       0.0
# 11  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.asc.aux.xml        False       NaN
# 12          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_ang.prj         True       0.0
# 13          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_cld.asc        False     100.0
# 14          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_cld.prj         True       0.0
# 15          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.asc         True       0.0
# 16  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.asc.aux.xml        False       NaN
# 17          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0610_150m_vel.prj         True       0.0
# 18              C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m.kmz        False       NaN
# 19          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.asc         True       0.0
# 20  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.asc.aux.xml        False       NaN
# 21          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_ang.prj         True       0.0
# 22          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_cld.asc        False     100.0
# 23          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_cld.prj         True       0.0
# 24          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.asc         True       0.0
# 25  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.asc.aux.xml        False       NaN
# 26          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0620_150m_vel.prj         True       0.0
# 27              C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m.kmz        False       NaN
# 28          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.asc         True       0.0
# 29  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.asc.aux.xml        False       NaN
# 30          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_ang.prj         True       0.0
# 31          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_cld.asc        False     100.0
# 32          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_cld.prj         True       0.0
# 33          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.asc         True       0.0
# 34  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.asc.aux.xml        False       NaN
# 35          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0630_150m_vel.prj         True       0.0
# 36              C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m.kmz        False       NaN
# 37          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.asc         True       0.0
# 38  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.asc.aux.xml        False       NaN
# 39          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_ang.prj         True       0.0
# 40          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_cld.asc        False     100.0
# 41          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_cld.prj         True       0.0
# 42          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.asc         True       0.0
# 43  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.asc.aux.xml        False       NaN
# 44          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0640_150m_vel.prj         True       0.0
# 45              C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m.kmz              C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m.kmz        False       NaN
# 46          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.asc         True       0.0
# 47  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.asc.aux.xml        False       NaN
# 48          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_ang.prj         True       0.0
# 49          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_cld.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_cld.asc        False     100.0
# 50          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_cld.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_cld.prj         True       0.0
# 51          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.asc          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.asc         True       0.0
# 52  C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.asc.aux.xml  C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.asc.aux.xml        False       NaN
# 53          C:\Users\A\Documents\WINDNINJA\00_Output_2025-08-31_all day_Google earth_Fire_150m_10min\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.prj          C:\Users\A\Documents\XX_GitHub_Repo\data-waves\windninja\windninja_output\Output_2025-08-31_0600-0650_Google earth_Fire_150m_10min\merlingen_7.5mi_point_08-31-2025_0650_150m_vel.prj         True       0.0
